# %%
import pandas as pd 
import numpy as np

# %%
# df=pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG (1).csv')
df=pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG (1).csv',encoding='latin-1')

# %%
df.head(10)
# Out:
#    Area Code     Area  Item Code              Item  Element Code  \
# 0          4  Algeria       2501        Population           511
# 1          4  Algeria       2501        Population          5301
# 2          4  Algeria       2901       Grand Total           664
# 3          4  Algeria       2901       Grand Total           674
# 4          4  Algeria       2901       Grand Total           684
# 5          4  Algeria       2903  Vegetal Products           664
# 6          4  Algeria       2903  Vegetal Products           674
# 7          4  Algeria       2903  Vegetal Products           684
# 8          4  Algeria       2941   Animal Products           664
# 9          4  Algeria       2941   Animal Products           674
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# ...

# %%
df2 = df['Element'].unique()

# %% [markdown]
# QUES 1:- HERE WE CAN SEE THE REQUIRED DATA
# Animal Fat produced in 2014-**209460.54**
# IN 2017-**269617.53**

# %%
df2 = df.groupby('Item').sum()
df2
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %% [markdown]
# QUES-2
# STD=1603.40
# MEAN=135.23

# %%
df['Y2015'].std()
# Out:
# 1603.4039839425013

# %%
df['Y2015'].mean()
# Out:
# 135.23596649549626

# %% [markdown]
# QUES 3-
# null=total_rows-not_null
# nul=60943-59408
# null=1535

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %% [markdown]
# QUES 4- HERE WE SEE THAT HIGHEST CRRELATIONI S WITH YEAR 2014

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %% [markdown]
# QUES-5-HERE WE CAN SEE HIGHEST IMPORT IS  OF  2017

# %%
df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# QUES-6,7-HERE WE CAN SEE PRODUCTION OF YEAR 2014 IS 1931287.75
# FOR QUES 7- We can see that Domestic supply quantity has highest sum

# %%
df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# QUES-8-Here we can see that the 3rd lowest sum in 2018 is Protein supply quantity (g/capita/day)

# %%
df2=df.groupby('Element').sum()
df2.nsmallest(3,'Y2018')
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Tourist consumption                         50308    1486528       2869905
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Protein supply quantity (g/capita/day)     675050   13535000       3385502
#
#                                            Y2014     Y2015     Y2016  \
# Element
# Tourist consumption                       416.00    349.00     89.00
# Fat supply quantity (g/capita/day)      10225.56  10235.74  10102.77
# Protein supply quantity (g/capita/day)  11836.46  11833.95  11779.69
#
#                                            Y2017     Y2018
# Element
# Tourist consumption                        91.00     90.00
# Fat supply quantity (g/capita/day)      10253.84  10258.69
# Protein supply quantity (g/capita/day)  11842.45  11833.56

# %% [markdown]
# QUES-9- Here we can see that total Import Quantity in Algeria in 2018 is **36238.29**

# %%
df.groupby(['Area','Element']).sum().head(10)
# Out:
#                                              Area Code  Item Code  \
# Area    Element
# Algeria Domestic supply quantity                   464     311204
#         Export Quantity                            392     264011
#         Fat supply quantity (g/capita/day)         432     291489
#         Feed                                        88      58967
#         Food                                       420     282744
#         Food supply (kcal/capita/day)              432     291489
#         Food supply quantity (kg/capita/yr)        420     282744
#         Import Quantity                            448     301030
#         Losses                                     208     139857
#         Other uses (non-food)                      148     101269
#
#                                              Element Code     Y2014     Y2015  \
# Area    Element
# Algeria Domestic supply quantity                   614916  83755.94  85972.86
# ...

# %% [markdown]
# QUES-10-total number of unique countries in the dataset is 49

# %%
df2 = df['Area'].unique()
len(df2)
# Out:
# 49
